# %%
import os
print os.getcwd()
# Out:
# /home/greatskull/Course 1

# %%
import graphlab

# %%
import graphlab

# %%
sf = graphlab.SFrame('people-example.csv')
# Out:
# Finished parsing file /home/greatskull/Course 1/people-example.csv
# Parsing completed. Parsed 7 lines in 0.009555 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,str,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /home/greatskull/Course 1/people-example.csv
# Parsing completed. Parsed 7 lines in 0.009711 secs.

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |    Bob     |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |    Bob     |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
sf = graphlab.SFrame('people-example.csv')
# Out:
# Finished parsing file /home/greatskull/Course 1/people-example.csv
# Parsing completed. Parsed 7 lines in 0.073818 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,str,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /home/greatskull/Course 1/people-example.csv
# Parsing completed. Parsed 7 lines in 0.069251 secs.

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |   Tanay    |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
sf.head(2)
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 2
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |   Tanay    |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# +------------+-----------+---------------+-----+
# [2 rows x 4 columns]

# %%
sf.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1830b8800d42> in <module>()
# ----> 1 sf.describe()
#
# AttributeError: 'SFrame' object has no attribute 'describe'

# %%
sf.head(5)
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 5
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |   Tanay    |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# +------------+-----------+---------------+-----+
# [5 rows x 4 columns]

# %%
sf.head()
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |   Tanay    |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
xx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-102f5037fe64> in <module>()
# ----> 1 xx
#
# NameError: name 'xx' is not defined

# %%
xx = graphlab.SFrame('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
# Out:
# Downloading https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data/dir_archive.ini to /var/tmp/graphlab-greatskull/32117/2d680367-6f0f-4452-b8ff-4e5a1ae8bfb4.ini
# Failed to download https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data/dir_archive.ini: HTTP response code said error
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-8fce42187328> in <module>()
# ----> 1 xx = graphlab.SFrame('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
#
# /home/greatskull/anaconda2/lib/python2.7/site-packages/graphlab/data_structures/sframe.pyc in __init__(self, data, format, _proxy)
#     951                     pass
#     952                 else:
# --> 953                     raise ValueError('Unknown input type: ' + format)
#     954
#     955         sframe_size = -1
#
# /home/greatskull/anaconda2/lib/python2.7/site-packages/graphlab/cython/context.pyc in __exit__(self, exc_type, exc_value, traceback)
#      47             if not self.show_cython_trace:
#      48                 # To hide cython trace, we re-raise from here
# ---> 49                 raise exc_type(exc_value)
#      50             else:
#      51                 # To show the full trace, we do nothing and let exception propagate
#
# RuntimeError: Runtime Exception. Unable to parse frame index file https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

# %%
xx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-102f5037fe64> in <module>()
# ----> 1 xx
#
# NameError: name 'xx' is not defined

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |   Tanay    |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
sf.head()[1][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-882c053c332c> in <module>()
# ----> 1 sf.head()[1][0]
#
# KeyError: 0

# %%
sf.show()
# Out:
# Canvas is updated and available in a tab in the default browser.

# %%
graphlab.canvas.set_target('ipynb')

# %%
sf['Country'].show(view='Categorical')

# %%
sf['Country']
# Out:
# dtype: str
# Rows: 7
# ['United States', 'Canada', 'England', 'USA', 'Poland', 'United States', 'Switzerland']

# %%
sf['Country'].show()

# %%
sf['Country'].mean()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-ad54b018fe68> in <module>()
# ----> 1 sf['Country'].mean()
#
# /home/greatskull/anaconda2/lib/python2.7/site-packages/graphlab/data_structures/sarray.pyc in mean(self)
#    2236                 return extensions.generate_mean(self)
#    2237             else:
# -> 2238                 return self.__proxy__.mean()
#    2239
#    2240
#
# /home/greatskull/anaconda2/lib/python2.7/site-packages/graphlab/cython/context.pyc in __exit__(self, exc_type, exc_value, traceback)
#      47             if not self.show_cython_trace:
#      48                 # To hide cython trace, we re-raise from here
# ---> 49                 raise exc_type(exc_value)
#      50             else:
#      51                 # To show the full trace, we do nothing and let exception propagate
#
# RuntimeError: Runtime Exception. Cannot perform on types that are not numeric or vector!

# %%
sf['age'].mean()
# Out:
# 23.142857142857146

# %%
sf['age'].min()
# Out:
# 22

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+
# | First Name | Last Name |    Country    | age |
# +------------+-----------+---------------+-----+
# |   Tanay    |   Smith   | United States |  24 |
# |   Alice    |  Williams |     Canada    |  23 |
# |  Malcolm   |    Jone   |    England    |  22 |
# |   Felix    |   Brown   |      USA      |  23 |
# |    Alex    |   Cooper  |     Poland    |  23 |
# |    Tod     |  Campbell | United States |  22 |
# |   Derek    |    Ward   |  Switzerland  |  25 |
# +------------+-----------+---------------+-----+
# [7 rows x 4 columns]

# %%
sf['Fuck'] = sf['First Name'] + ' ' + sf['Last Name']

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
# 	Fuck	str
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+----------------+
# | First Name | Last Name |    Country    | age |      Fuck      |
# +------------+-----------+---------------+-----+----------------+
# |   Tanay    |   Smith   | United States |  24 |  Tanay Smith   |
# |   Alice    |  Williams |     Canada    |  23 | Alice Williams |
# |  Malcolm   |    Jone   |    England    |  22 |  Malcolm Jone  |
# |   Felix    |   Brown   |      USA      |  23 |  Felix Brown   |
# |    Alex    |   Cooper  |     Poland    |  23 |  Alex Cooper   |
# |    Tod     |  Campbell | United States |  22 |  Tod Campbell  |
# |   Derek    |    Ward   |  Switzerland  |  25 |   Derek Ward   |
# +------------+-----------+---------------+-----+----------------+
# [7 rows x 5 columns]

# %%
for i in sf['Country']:
    if i=='USA':
        i = 'United States'

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
# 	Fuck	str
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+----------------+
# | First Name | Last Name |    Country    | age |      Fuck      |
# +------------+-----------+---------------+-----+----------------+
# |   Tanay    |   Smith   | United States |  24 |  Tanay Smith   |
# |   Alice    |  Williams |     Canada    |  23 | Alice Williams |
# |  Malcolm   |    Jone   |    England    |  22 |  Malcolm Jone  |
# |   Felix    |   Brown   |      USA      |  23 |  Felix Brown   |
# |    Alex    |   Cooper  |     Poland    |  23 |  Alex Cooper   |
# |    Tod     |  Campbell | United States |  22 |  Tod Campbell  |
# |   Derek    |    Ward   |  Switzerland  |  25 |   Derek Ward   |
# +------------+-----------+---------------+-----+----------------+
# [7 rows x 5 columns]

# %%
i
# Out:
# 'Switzerland'

# %%
for i in sf['Country']:
    if i=='USA':
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-6002fe2358ee> in <module>()
#       1 for i in sf['Country']:
#       2     if i=='USA':
# ----> 3         sf.delete(sf[i])
#       4         sf.insert(i,'United States')
#
# AttributeError: 'SFrame' object has no attribute 'delete'

# %%
ab = lambda x if x=='USA': 'United States'
# Out:
#   File "<ipython-input-38-b955665b2bc2>", line 1
#     ab = lambda x if x=='USA': 'United States'
#                    ^
# SyntaxError: invalid syntax

# %%
def tc(c):
    if c == 'USA':
        return 'United States'
    else:
        return c

# %%
sf['Country'] = sf['Country'].apply(tc)

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
# 	Fuck	str
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+----------------+
# | First Name | Last Name |    Country    | age |      Fuck      |
# +------------+-----------+---------------+-----+----------------+
# |   Tanay    |   Smith   | United States |  24 |  Tanay Smith   |
# |   Alice    |  Williams |     Canada    |  23 | Alice Williams |
# |  Malcolm   |    Jone   |    England    |  22 |  Malcolm Jone  |
# |   Felix    |   Brown   | United States |  23 |  Felix Brown   |
# |    Alex    |   Cooper  |     Poland    |  23 |  Alex Cooper   |
# |    Tod     |  Campbell | United States |  22 |  Tod Campbell  |
# |   Derek    |    Ward   |  Switzerland  |  25 |   Derek Ward   |
# +------------+-----------+---------------+-----+----------------+
# [7 rows x 5 columns]

# %%
sf
# Out:
# Columns:
# 	First Name	str
# 	Last Name	str
# 	Country	str
# 	age	int
# 	Fuck	str
#
# Rows: 7
#
# Data:
# +------------+-----------+---------------+-----+----------------+
# | First Name | Last Name |    Country    | age |      Fuck      |
# +------------+-----------+---------------+-----+----------------+
# |   Tanay    |   Smith   | United States |  24 |  Tanay Smith   |
# |   Alice    |  Williams |     Canada    |  23 | Alice Williams |
# |  Malcolm   |    Jone   |    England    |  22 |  Malcolm Jone  |
# |   Felix    |   Brown   | United States |  23 |  Felix Brown   |
# |    Alex    |   Cooper  |     Poland    |  23 |  Alex Cooper   |
# |    Tod     |  Campbell | United States |  22 |  Tod Campbell  |
# |   Derek    |    Ward   |  Switzerland  |  25 |   Derek Ward   |
# +------------+-----------+---------------+-----+----------------+
# [7 rows x 5 columns]

# %%
print 'Tnay'

# %%
import os

# %%
print os.getcwd()
